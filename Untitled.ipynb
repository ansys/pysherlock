# %%
from ansys.sherlock.core import launcher
sherlock = launcher.launch_sherlock()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ansys.sherlock.core import launcher
#       2 sherlock = launcher.launch_sherlock()
#
# File ~\PycharmProjects\pysherlock\src\ansys\sherlock\core\launcher.py:15
#      13 from ansys.sherlock.core import LOG
#      14 from ansys.sherlock.core.errors import SherlockCannotUsePortError, SherlockConnectionError
# ---> 15 from ansys.sherlock.core.sherlock import Sherlock
#      17 LOCALHOST = "127.0.0.1"
#      18 SHERLOCK_DEFAULT_PORT = 9090
#
# File ~\PycharmProjects\pysherlock\src\ansys\sherlock\core\sherlock.py:4
#       1 # © 2023 ANSYS, Inc. All rights reserved
#       3 """Module for the gRPC connection object."""
# ----> 4 from ansys.sherlock.core.analysis import Analysis
#       5 from ansys.sherlock.core.common import Common
#       6 from ansys.sherlock.core.layer import Layer
#
# ...
